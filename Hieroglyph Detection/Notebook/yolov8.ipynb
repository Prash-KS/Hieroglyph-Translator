# %% [markdown]
# #

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/aaaaaa/image.png
# /kaggle/input/mmmmmm/image.png
# /kaggle/input/aa2600/050326_Aa26.png
# /kaggle/input/wwwwww/image.png
# /kaggle/input/yaml01/yaml01.yaml
# /kaggle/input/yolomodel/best.pt
# /kaggle/input/ssssss/image.jpg
# /kaggle/input/dataset1/dataset1/labels/train/070069_D21.txt
# /kaggle/input/dataset1/dataset1/labels/train/070146_N35.txt
# /kaggle/input/dataset1/dataset1/labels/train/210039_S29.txt
# /kaggle/input/dataset1/dataset1/labels/train/200190_S29.txt
# /kaggle/input/dataset1/dataset1/labels/train/070261_F16.txt
# /kaggle/input/dataset1/dataset1/labels/train/030253_N18.txt
# /kaggle/input/dataset1/dataset1/labels/train/200292_V31.txt
# /kaggle/input/dataset1/dataset1/labels/train/200111_Q7.txt
# /kaggle/input/dataset1/dataset1/labels/train/410331_D21.txt
# /kaggle/input/dataset1/dataset1/labels/train/070226_N35.txt
# /kaggle/input/dataset1/dataset1/labels/train/390280_N5.txt
# /kaggle/input/dataset1/dataset1/labels/train/390160_V31.txt
# ...

# %%
import os
os.environ['WANDB_DISABLED'] = 'true'

# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 881.3/881.3 kB 15.7 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolov8n.yaml")  # build a new model from scratch

# Use the model
results = model.train(data="/kaggle/input/yaml01/yaml01.yaml", epochs=5, save = True)  # train the model
# Out:
# Ultralytics YOLOv8.2.97 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# Load the trained model
from ultralytics import YOLO
model = YOLO("/kaggle/input/yolomodel/best.pt")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# Perform inference on a new image
results = model("/kaggle/input/wwwwww/image.png")
# Out:
# image 1/1 /kaggle/input/wwwwww/image.png: 256x640 3 hieroglyphs, 79.5ms
# Speed: 10.1ms preprocess, 79.5ms inference, 221.3ms postprocess per image at shape (1, 3, 256, 640)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Extract the result
result = results[0]

# Plot the image with detections
plt.figure(figsize=(10, 10))
plt.imshow(result.plot())  # Plot the result directly
plt.axis('off')  # Turn off axis
plt.show()
